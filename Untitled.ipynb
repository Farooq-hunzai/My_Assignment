# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# **Farooq Aziz**
#
# (Data scientist)

# %% [markdown]
# *I am interested in Data Science because I would love to contribute towards affordable and quality healthcare in the future*

# %% [markdown]
# ### the following code tests the pythagorus  formula

# %% [markdown]
# $ x^2 + y^2 = z^2 $

# %% [markdown]
# #### Horizontal line rule
# Data
# ***
# Content
# 1. - date
# 2. - day
# 3. - month
#
# | content     | Description |
# | ----------- | ----------- |
# | Header      | Title       |
# | Paragraph   | Text        |
#
#
# https://www.coursera.org/
#
#
#
#
# ![1665687451547.jfif](attachment:6c56e350-263d-4f28-a211-e1290c0e7d2e.jfif)
#
#
# <font color=blue>This text to be show in blue</font>
# <font color=pink>The text to be show in pink</font>
#
# > Change is the measure of intelligence.
#
# ~~The END~~
